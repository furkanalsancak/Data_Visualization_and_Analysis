# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
x = [1,   3,  5,  7,  9, 11] #x and y must have same dimensions/length
y = [13, 17, 20, 21, 24, 25]

plt.plot(x,y)
# plt.savefig('first_data_jpg') # saves graph as png
# plt.scatter(x,y) # creates scatter plot

# %%
x = [1,   3,  5,  7,  9, 11] 
y = [13, 17, 20, 21, 24, 25]

plt.scatter(x,y)

# %%
x = np.linspace(0, 25, 150) 
y = 4 + 2 * np.sin(2 * x)

plt.plot(x, y)
