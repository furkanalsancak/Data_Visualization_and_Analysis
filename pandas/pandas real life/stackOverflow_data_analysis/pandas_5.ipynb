# %%
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('survey_results_schema.csv', index_col='Column')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# 4           The quality of OSS and closed source software ...
# 5           OSS is, on average, of HIGHER quality than pro...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# 2               Not employed, but looking for work  Bosnia and Herzegovina
# 3                               Employed full-time                Thailand
# 4                               Employed full-time           United States
# 5                               Employed full-time                 Ukraine
#
#                    Student                                            EdLevel  \
# Respondent
# 1                       No                          Primary/elementary school
# 2           Yes, full-time  Secondary school (e.g. American high school, G...
# 3                       No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4                       No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 5                       No           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                                UndergradMajor  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                               Web development or web design
# 4           Computer science, computer engineering, or sof...
# 5           Computer science, computer engineering, or sof...
#
#                                                      EduOther  \
# Respondent
# 1           Taught yourself a new language, framework, or ...
# 2           Taken an online course in programming or softw...
# 3           Taught yourself a new language, framework, or ...
# 4           Taken an online course in programming or softw...
# 5           Taken an online course in programming or softw...
#
#                              OrgSize  \
# Respondent
# 1                                NaN
# 2                                NaN
# 3               100 to 499 employees
# 4               100 to 499 employees
# 5           10,000 or more employees
#
#                                                       DevType YearsCode  \
# Respondent
# 1                                                         NaN         4
# 2           Developer, desktop or enterprise applications;...       NaN
# 3           Designer;Developer, back-end;Developer, front-...         3
# 4                                       Developer, full-stack         3
# 5           Academic researcher;Developer, desktop or ente...        16
#
#            Age1stCode      YearsCodePro           CareerSat  \
# Respondent
# 1                  10               NaN                 NaN
# 2                  17               NaN                 NaN
# 3                  22                 1  Slightly satisfied
# 4                  16  Less than 1 year      Very satisfied
# 5                  14                 9   Very dissatisfied
#
#                            JobSat              MgrIdiot  MgrMoney   MgrWant  \
# Respondent
# 1                             NaN                   NaN       NaN       NaN
# 2                             NaN                   NaN       NaN       NaN
# 3              Slightly satisfied  Not at all confident  Not sure  Not sure
# 4              Slightly satisfied        Very confident        No  Not sure
# 5           Slightly dissatisfied    Somewhat confident       Yes        No
#
#                                                       JobSeek  \
# Respondent
# 1                                                         NaN
# 2                             I am actively looking for a job
# 3           I’m not actively looking, but I am open to new...
# 4                I am not interested in new job opportunities
# 5                I am not interested in new job opportunities
#
#                     LastHireDate  \
# Respondent
# 1                            NaN
# 2           I've never had a job
# 3                  1-2 years ago
# 4           Less than a year ago
# 5           Less than a year ago
#
#                                                       LastInt FizzBuzz  \
# Respondent
# 1                                                         NaN      NaN
# 2                                                         NaN      NaN
# 3                         Interview with people in peer roles       No
# 4           Write code by hand (e.g., on a whiteboard);Int...       No
# 5           Write any code;Write code by hand (e.g., on a ...       No
#
#                                                    JobFactors  \
# Respondent
# 1                                                         NaN
# 2           Financial performance or funding status of the...
# 3           Languages, frameworks, and other technologies ...
# 4           Languages, frameworks, and other technologies ...
# 5           Industry that I'd be working in;Languages, fra...
#
#                                                  ResumeUpdate CurrencySymbol  \
# Respondent
# 1                                                         NaN            NaN
# 2           Something else changed (education, award, medi...            NaN
# 3                            I was preparing for a job search            THB
# 4                            I was preparing for a job search            USD
# 5                            I was preparing for a job search            UAH
#
#                     CurrencyDesc  CompTotal CompFreq  ConvertedComp  \
# Respondent
# 1                            NaN        NaN      NaN            NaN
# 2                            NaN        NaN      NaN            NaN
# 3                      Thai baht    23000.0  Monthly         8820.0
# 4           United States dollar    61000.0   Yearly        61000.0
# 5              Ukrainian hryvnia        NaN      NaN            NaN
#
#             WorkWeekHrs                                           WorkPlan  \
# Respondent
# 1                   NaN                                                NaN
# 2                   NaN                                                NaN
# 3                  40.0  There's no schedule or spec; I work on what se...
# 4                  80.0  There's no schedule or spec; I work on what se...
# 5                  55.0  There is a schedule and/or spec (made by me or...
#
#                                                 WorkChallenge  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3           Distracting work environment;Inadequate access...
# 4                                                         NaN
# 5           Being tasked with non-development work;Inadequ...
#
#                                   WorkRemote WorkLoc                  ImpSyn  \
# Respondent
# 1                                        NaN     NaN                     NaN
# 2                                        NaN     NaN                     NaN
# 3           Less than once per month / Never    Home                 Average
# 4           Less than once per month / Never    Home  A little below average
# 5                      A few days each month  Office  A little above average
#
#                                             CodeRev  CodeRevHrs  \
# Respondent
# 1                                               NaN         NaN
# 2                                               NaN         NaN
# 3                                                No         NaN
# 4                                                No         NaN
# 5           Yes, because I see value in code review         NaN
#
#                                 UnitTests  \
# Respondent
# 1                                     NaN
# 2                                     NaN
# 3               No, but I think we should
# 4               No, but I think we should
# 5           Yes, it's part of our process
#
#                                                   PurchaseHow  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                                                    Not sure
# 4           Developers typically have the most influence o...
# 5                                                    Not sure
#
#                              PurchaseWhat  \
# Respondent
# 1                                     NaN
# 2                                     NaN
# 3           I have little or no influence
# 4           I have little or no influence
# 5           I have little or no influence
#
#                                      LanguageWorkedWith  \
# Respondent
# 1                       HTML/CSS;Java;JavaScript;Python
# 2                                   C++;HTML/CSS;Python
# 3                                              HTML/CSS
# 4                                   C;C++;C#;Python;SQL
# 5           C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
#
#                                      LanguageDesireNextYear  \
# Respondent
# 1           C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL
# 2                               C++;HTML/CSS;JavaScript;SQL
# 3                                           Elixir;HTML/CSS
# 4                                       C;C#;JavaScript;SQL
# 5                  HTML/CSS;Java;JavaScript;SQL;WebAssembly
#
#                                           DatabaseWorkedWith  \
# Respondent
# 1                                                     SQLite
# 2                                                        NaN
# 3                                                 PostgreSQL
# 4                                               MySQL;SQLite
# 5           Couchbase;MongoDB;MySQL;Oracle;PostgreSQL;SQLite
#
#                                        DatabaseDesireNextYear  \
# Respondent
# 1                                                       MySQL
# 2                                                       MySQL
# 3                                                  PostgreSQL
# 4                                                MySQL;SQLite
# 5           Couchbase;Firebase;MongoDB;MySQL;Oracle;Postgr...
#
#                            PlatformWorkedWith  \
# Respondent
# 1                               MacOS;Windows
# 2                                     Windows
# 3                                         NaN
# 4                               Linux;Windows
# 5           Android;Linux;MacOS;Slack;Windows
#
#                            PlatformDesireNextYear  \
# Respondent
# 1                         Android;Arduino;Windows
# 2                                         Windows
# 3                                             NaN
# 4                                   Linux;Windows
# 5           Android;Docker;Kubernetes;Linux;Slack
#
#                                      WebFrameWorkedWith  \
# Respondent
# 1                                          Django;Flask
# 2                                                Django
# 3                                                   NaN
# 4                                                   NaN
# 5           Django;Express;Flask;jQuery;React.js;Spring
#
#                   WebFrameDesireNextYear MiscTechWorkedWith  \
# Respondent
# 1                           Flask;jQuery            Node.js
# 2                                 Django                NaN
# 3                              Other(s):                NaN
# 4                                    NaN               .NET
# 5           Flask;jQuery;React.js;Spring    Cordova;Node.js
#
#                               MiscTechDesireNextYear  \
# Respondent
# 1                                            Node.js
# 2                                                NaN
# 3                                                NaN
# 4                                               .NET
# 5           Apache Spark;Hadoop;Node.js;React Native
#
#                                               DevEnviron        OpSys  \
# Respondent
# 1                             IntelliJ;Notepad++;PyCharm      Windows
# 2                                           Atom;PyCharm      Windows
# 3                                 Vim;Visual Studio Code  Linux-based
# 4           Eclipse;Vim;Visual Studio;Visual Studio Code      Windows
# 5                                 IntelliJ;Notepad++;Vim  Linux-based
#
#                                         Containers BlockchainOrg  \
# Respondent
# 1                          I do not use containers           NaN
# 2                          I do not use containers           NaN
# 3                          I do not use containers           NaN
# 4                          I do not use containers    Not at all
# 5           Outside of work, for personal projects    Not at all
#
#                                                  BlockchainIs BetterLife  \
# Respondent
# 1                                                         NaN        Yes
# 2           Useful across many domains and could change ma...        Yes
# 3                                                         NaN        Yes
# 4           Useful for decentralized currency (i.e., Bitcoin)        Yes
# 5                                                         NaN        Yes
#
#                                             ITperson OffOn SocialMedia  \
# Respondent
# 1           Fortunately, someone else has that title   Yes     Twitter
# 2                                                Yes   Yes   Instagram
# 3                                                Yes   Yes      Reddit
# 4                                               SIGH   Yes      Reddit
# 5                                           Also Yes   Yes    Facebook
#
#                         Extraversion ScreenName        SOVisit1st  \
# Respondent
# 1                             Online   Username              2017
# 2                             Online   Username              2017
# 3           In real life (in person)   Username              2011
# 4           In real life (in person)   Username              2014
# 5           In real life (in person)   Username  I don't remember
#
#                                 SOVisitFreq  \
# Respondent
# 1           A few times per month or weekly
# 2                     Daily or almost daily
# 3                      A few times per week
# 4                     Daily or almost daily
# 5                    Multiple times per day
#
#                                                     SOVisitTo  \
# Respondent
# 1           Find answers to specific questions;Learn how t...
# 2           Find answers to specific questions;Learn how t...
# 3           Find answers to specific questions;Learn how t...
# 4           Find answers to specific questions;Pass the ti...
# 5                          Find answers to specific questions
#
#                            SOFindAnswer                     SOTimeSaved  \
# Respondent
# 1                    3-5 times per week  Stack Overflow was much faster
# 2                    3-5 times per week  Stack Overflow was much faster
# 3                   6-10 times per week        They were about the same
# 4                    1-2 times per week  Stack Overflow was much faster
# 5           More than 10 times per week  Stack Overflow was much faster
#
#             SOHowMuchTime SOAccount                           SOPartFreq  \
# Respondent
# 1           31-60 minutes        No                                  NaN
# 2           11-30 minutes       Yes      A few times per month or weekly
# 3                     NaN       Yes  Less than once per month or monthly
# 4           31-60 minutes       Yes  Less than once per month or monthly
# 5                     NaN       Yes      A few times per month or weekly
#
#                                                        SOJobs  \
# Respondent
# 1           No, I didn't know that Stack Overflow had a jo...
# 2           No, I knew that Stack Overflow had a job board...
# 3                                                         Yes
# 4                                                         Yes
# 5           No, I knew that Stack Overflow had a job board...
#
#                                                      EntTeams  \
# Respondent
# 1                         No, and I don't know what those are
# 2                         No, and I don't know what those are
# 3           No, I've heard of them, but I am not part of a...
# 4                         No, and I don't know what those are
# 5           No, I've heard of them, but I am not part of a...
#
#                      SOComm                            WelcomeChange  \
# Respondent
# 1                   Neutral  Just as welcome now as I felt last year
# 2             Yes, somewhat  Just as welcome now as I felt last year
# 3                   Neutral  Just as welcome now as I felt last year
# 4            No, not really  Just as welcome now as I felt last year
# 5           Yes, definitely  Just as welcome now as I felt last year
#
#                                                  SONewContent   Age Gender  \
# Respondent
# 1           Tech articles written by other developers;Indu...  14.0    Man
# 2           Tech articles written by other developers;Indu...  19.0    Man
# 3           Tech meetups or events in your area;Courses on...  28.0    Man
# 4           Tech articles written by other developers;Indu...  22.0    Man
# 5           Tech meetups or events in your area;Courses on...  30.0    Man
#
#            Trans                Sexuality  \
# Respondent
# 1             No  Straight / Heterosexual
# 2             No  Straight / Heterosexual
# 3             No  Straight / Heterosexual
# 4             No  Straight / Heterosexual
# 5             No  Straight / Heterosexual
#
#                                            Ethnicity Dependents  \
# Respondent
# 1                                                NaN         No
# 2                                                NaN         No
# 3                                                NaN        Yes
# 4                       White or of European descent         No
# 5           White or of European descent;Multiracial         No
#
#                      SurveyLength                  SurveyEase
# Respondent
# 1           Appropriate in length  Neither easy nor difficult
# 2           Appropriate in length  Neither easy nor difficult
# 3           Appropriate in length  Neither easy nor difficult
# 4           Appropriate in length                        Easy
# 5           Appropriate in length                        Easy

# %%
df.rename(columns={'ConvertedComp': 'SalaryUSD'}, inplace=True)

# %%
df['SalaryUSD']
# Out:
# Respondent
# 1             NaN
# 2             NaN
# 3          8820.0
# 4         61000.0
# 5             NaN
#            ...
# 43135         NaN
# 43136    350000.0
# 43137         NaN
# 43138         NaN
# 43139     26232.0
# Name: SalaryUSD, Length: 42866, dtype: float64

# %%
df['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4         No
# 5        Yes
#         ...
# 43135    Yes
# 43136    Yes
# 43137    Yes
# 43138    Yes
# 43139    Yes
# Name: Hobbyist, Length: 42866, dtype: object

# %%
df['Hobbyist'].map({'Yes': True, 'No': False})
# Out:
# Respondent
# 1         True
# 2        False
# 3         True
# 4        False
# 5         True
#          ...
# 43135     True
# 43136     True
# 43137     True
# 43138     True
# 43139     True
# Name: Hobbyist, Length: 42866, dtype: bool

# %%
df['Hobbyist'] = df['Hobbyist'].map({'Yes': True, 'No': False})

# %%
df
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      True
# 2                      I am a student who is learning to code     False
# 3           I am not primarily a developer, but I write co...      True
# 4                              I am a developer by profession     False
# 5                              I am a developer by profession      True
# ...                                                       ...       ...
# 43135                  I am a student who is learning to code      True
# 43136                          I am a developer by profession      True
# 43137                          I am a developer by profession      True
# 43138                          I am a developer by profession      True
# 43139                          I am a developer by profession      True
#
#                                                   OpenSourcer  \
# Respondent
# 1                                                       Never
# 2                                     Less than once per year
# 3                                                       Never
# 4                                                       Never
# 5                                  Once a month or more often
# ...                                                       ...
# 43135                              Once a month or more often
# 43136                              Once a month or more often
# 43137                                 Less than once per year
# 43138                                 Less than once per year
# 43139       Less than once a month but more than once per ...
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# 4           The quality of OSS and closed source software ...
# 5           OSS is, on average, of HIGHER quality than pro...
# ...                                                       ...
# 43135       OSS is, on average, of HIGHER quality than pro...
# 43136       OSS is, on average, of HIGHER quality than pro...
# 43137       OSS is, on average, of HIGHER quality than pro...
# 43138       The quality of OSS and closed source software ...
# 43139       The quality of OSS and closed source software ...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# 2               Not employed, but looking for work  Bosnia and Herzegovina
# 3                               Employed full-time                Thailand
# 4                               Employed full-time           United States
# 5                               Employed full-time                 Ukraine
# ...                                            ...                     ...
# 43135           Not employed, but looking for work                   India
# 43136                           Employed full-time           United States
# 43137                           Employed full-time                   India
# 43138                           Employed full-time           United States
# 43139                           Employed full-time                  Brazil
#
#                    Student                                            EdLevel  \
# Respondent
# 1                       No                          Primary/elementary school
# 2           Yes, full-time  Secondary school (e.g. American high school, G...
# 3                       No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4                       No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 5                       No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...                    ...                                                ...
# 43135       Yes, full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 43136                   No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 43137                  NaN           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 43138                   No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 43139       Yes, part-time                 Professional degree (JD, MD, etc.)
#
#                                                UndergradMajor  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                               Web development or web design
# 4           Computer science, computer engineering, or sof...
# 5           Computer science, computer engineering, or sof...
# ...                                                       ...
# 43135       Information systems, information technology, o...
# 43136       A natural science (ex. biology, chemistry, phy...
# 43137                           Web development or web design
# 43138       Information systems, information technology, o...
# 43139                           Web development or web design
#
#                                                      EduOther  \
# Respondent
# 1           Taught yourself a new language, framework, or ...
# 2           Taken an online course in programming or softw...
# 3           Taught yourself a new language, framework, or ...
# 4           Taken an online course in programming or softw...
# 5           Taken an online course in programming or softw...
# ...                                                       ...
# 43135       Taken an online course in programming or softw...
# 43136       Taken an online course in programming or softw...
# 43137       Received on-the-job training in software devel...
# 43138       Taken an online course in programming or softw...
# 43139       Taken an online course in programming or softw...
#
#                              OrgSize  \
# Respondent
# 1                                NaN
# 2                                NaN
# 3               100 to 499 employees
# 4               100 to 499 employees
# 5           10,000 or more employees
# ...                              ...
# 43135                            NaN
# 43136       10,000 or more employees
# 43137           100 to 499 employees
# 43138       5,000 to 9,999 employees
# 43139       10,000 or more employees
#
#                                                       DevType YearsCode  \
# Respondent
# 1                                                         NaN         4
# 2           Developer, desktop or enterprise applications;...       NaN
# 3           Designer;Developer, back-end;Developer, front-...         3
# 4                                       Developer, full-stack         3
# 5           Academic researcher;Developer, desktop or ente...        16
# ...                                                       ...       ...
# 43135       Data scientist or machine learning specialist;...         3
# 43136       Academic researcher;Data or business analyst;D...        20
# 43137                Developer, back-end;Developer, front-end         4
# 43138            Database administrator;Developer, full-stack        16
# 43139       Academic researcher;Developer, back-end;Develo...        14
#
#            Age1stCode      YearsCodePro           CareerSat  \
# Respondent
# 1                  10               NaN                 NaN
# 2                  17               NaN                 NaN
# 3                  22                 1  Slightly satisfied
# 4                  16  Less than 1 year      Very satisfied
# 5                  14                 9   Very dissatisfied
# ...               ...               ...                 ...
# 43135              19               NaN                 NaN
# 43136               8                10      Very satisfied
# 43137              26                 4  Slightly satisfied
# 43138              18                12      Very satisfied
# 43139              14                10  Slightly satisfied
#
#                                         JobSat              MgrIdiot  \
# Respondent
# 1                                          NaN                   NaN
# 2                                          NaN                   NaN
# 3                           Slightly satisfied  Not at all confident
# 4                           Slightly satisfied        Very confident
# 5                        Slightly dissatisfied    Somewhat confident
# ...                                        ...                   ...
# 43135                                      NaN                   NaN
# 43136                           Very satisfied        Very confident
# 43137       Neither satisfied nor dissatisfied    Somewhat confident
# 43138       Neither satisfied nor dissatisfied    Somewhat confident
# 43139                       Slightly satisfied  Not at all confident
#
#             MgrMoney   MgrWant  \
# Respondent
# 1                NaN       NaN
# 2                NaN       NaN
# 3           Not sure  Not sure
# 4                 No  Not sure
# 5                Yes        No
# ...              ...       ...
# 43135            NaN       NaN
# 43136             No  Not sure
# 43137             No        No
# 43138            Yes        No
# 43139             No  Not sure
#
#                                                       JobSeek  \
# Respondent
# 1                                                         NaN
# 2                             I am actively looking for a job
# 3           I’m not actively looking, but I am open to new...
# 4                I am not interested in new job opportunities
# 5                I am not interested in new job opportunities
# ...                                                       ...
# 43135                         I am actively looking for a job
# 43136            I am not interested in new job opportunities
# 43137       I’m not actively looking, but I am open to new...
# 43138                         I am actively looking for a job
# 43139       I’m not actively looking, but I am open to new...
#
#                      LastHireDate  \
# Respondent
# 1                             NaN
# 2            I've never had a job
# 3                   1-2 years ago
# 4            Less than a year ago
# 5            Less than a year ago
# ...                           ...
# 43135        I've never had a job
# 43136        Less than a year ago
# 43137               1-2 years ago
# 43138       More than 4 years ago
# 43139               1-2 years ago
#
#                                                       LastInt FizzBuzz  \
# Respondent
# 1                                                         NaN      NaN
# 2                                                         NaN      NaN
# 3                         Interview with people in peer roles       No
# 4           Write code by hand (e.g., on a whiteboard);Int...       No
# 5           Write any code;Write code by hand (e.g., on a ...       No
# ...                                                       ...      ...
# 43135                                                     NaN      NaN
# 43136       Write any code;Write code by hand (e.g., on a ...       No
# 43137       Interview with people in senior / management r...       No
# 43138       Interview with people in peer roles;Interview ...       No
# 43139       Interview with people in peer roles;Interview ...      Yes
#
#                                                    JobFactors  \
# Respondent
# 1                                                         NaN
# 2           Financial performance or funding status of the...
# 3           Languages, frameworks, and other technologies ...
# 4           Languages, frameworks, and other technologies ...
# 5           Industry that I'd be working in;Languages, fra...
# ...                                                       ...
# 43135       Languages, frameworks, and other technologies ...
# 43136       Specific department or team I'd be working on;...
# 43137       Opportunities for professional development;Div...
# 43138       Languages, frameworks, and other technologies ...
# 43139       Industry that I'd be working in;Languages, fra...
#
#                                                  ResumeUpdate CurrencySymbol  \
# Respondent
# 1                                                         NaN            NaN
# 2           Something else changed (education, award, medi...            NaN
# 3                            I was preparing for a job search            THB
# 4                            I was preparing for a job search            USD
# 5                            I was preparing for a job search            UAH
# ...                                                       ...            ...
# 43135                        I was preparing for a job search            NaN
# 43136                        I was preparing for a job search            USD
# 43137       I heard about a job opportunity (from a recrui...            INR
# 43138                        I was preparing for a job search            USD
# 43139       I heard about a job opportunity (from a recrui...            BRL
#
#                     CurrencyDesc  CompTotal CompFreq  SalaryUSD  WorkWeekHrs  \
# Respondent
# 1                            NaN        NaN      NaN        NaN          NaN
# 2                            NaN        NaN      NaN        NaN          NaN
# 3                      Thai baht    23000.0  Monthly     8820.0         40.0
# 4           United States dollar    61000.0   Yearly    61000.0         80.0
# 5              Ukrainian hryvnia        NaN      NaN        NaN         55.0
# ...                          ...        ...      ...        ...          ...
# 43135                        NaN        NaN      NaN        NaN          NaN
# 43136       United States dollar   350000.0   Yearly   350000.0         80.0
# 43137               Indian rupee        NaN  Monthly        NaN          NaN
# 43138       United States dollar        NaN      NaN        NaN         40.0
# 43139             Brazilian real     8000.0  Monthly    26232.0         44.0
#
#                                                      WorkPlan  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3           There's no schedule or spec; I work on what se...
# 4           There's no schedule or spec; I work on what se...
# 5           There is a schedule and/or spec (made by me or...
# ...                                                       ...
# 43135                                                     NaN
# 43136       There's no schedule or spec; I work on what se...
# 43137       There's no schedule or spec; I work on what se...
# 43138       There's no schedule or spec; I work on what se...
# 43139       There is a schedule and/or spec (made by me or...
#
#                                                 WorkChallenge  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3           Distracting work environment;Inadequate access...
# 4                                                         NaN
# 5           Being tasked with non-development work;Inadequ...
# ...                                                       ...
# 43135                                                     NaN
# 43136       Being tasked with non-development work;Meeting...
# 43137       Distracting work environment;Lack of support f...
# 43138       Distracting work environment;Time spent commut...
# 43139       Distracting work environment;Inadequate access...
#
#                                   WorkRemote WorkLoc                  ImpSyn  \
# Respondent
# 1                                        NaN     NaN                     NaN
# 2                                        NaN     NaN                     NaN
# 3           Less than once per month / Never    Home                 Average
# 4           Less than once per month / Never    Home  A little below average
# 5                      A few days each month  Office  A little above average
# ...                                      ...     ...                     ...
# 43135                                    NaN     NaN                     NaN
# 43136                       It's complicated  Office                 Average
# 43137       Less than once per month / Never    Home                 Average
# 43138                  A few days each month    Home  A little above average
# 43139       Less than once per month / Never    Home  A little above average
#
#                                             CodeRev  CodeRevHrs  \
# Respondent
# 1                                               NaN         NaN
# 2                                               NaN         NaN
# 3                                                No         NaN
# 4                                                No         NaN
# 5           Yes, because I see value in code review         NaN
# ...                                             ...         ...
# 43135                                           NaN         NaN
# 43136       Yes, because I see value in code review         2.0
# 43137                                            No         NaN
# 43138                                            No         NaN
# 43139       Yes, because I see value in code review         2.0
#
#                                                     UnitTests  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                                   No, but I think we should
# 4                                   No, but I think we should
# 5                               Yes, it's part of our process
# ...                                                       ...
# 43135                                                     NaN
# 43136                           Yes, it's part of our process
# 43137                           Yes, it's part of our process
# 43138                               No, but I think we should
# 43139       Yes, it's not part of our process but the deve...
#
#                                                   PurchaseHow  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                                                    Not sure
# 4           Developers typically have the most influence o...
# 5                                                    Not sure
# ...                                                       ...
# 43135                                                     NaN
# 43136       Developers typically have the most influence o...
# 43137                                                Not sure
# 43138       The CTO, CIO, or other management purchase new...
# 43139       The CTO, CIO, or other management purchase new...
#
#                              PurchaseWhat  \
# Respondent
# 1                                     NaN
# 2                                     NaN
# 3           I have little or no influence
# 4           I have little or no influence
# 5           I have little or no influence
# ...                                   ...
# 43135                                 NaN
# 43136               I have some influence
# 43137       I have little or no influence
# 43138       I have little or no influence
# 43139               I have some influence
#
#                                            LanguageWorkedWith  \
# Respondent
# 1                             HTML/CSS;Java;JavaScript;Python
# 2                                         C++;HTML/CSS;Python
# 3                                                    HTML/CSS
# 4                                         C;C++;C#;Python;SQL
# 5                 C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# ...                                                       ...
# 43135                                        C;C++;Python;SQL
# 43136       Bash/Shell/PowerShell;C++;C#;HTML/CSS;JavaScri...
# 43137                                                 PHP;SQL
# 43138                       HTML/CSS;JavaScript;SQL;Other(s):
# 43139                              C#;HTML/CSS;JavaScript;SQL
#
#                                        LanguageDesireNextYear  \
# Respondent
# 1             C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL
# 2                                 C++;HTML/CSS;JavaScript;SQL
# 3                                             Elixir;HTML/CSS
# 4                                         C;C#;JavaScript;SQL
# 5                    HTML/CSS;Java;JavaScript;SQL;WebAssembly
# ...                                                       ...
# 43135       Bash/Shell/PowerShell;C#;Elixir;Go;Java;Kotlin...
# 43136       Bash/Shell/PowerShell;Go;HTML/CSS;JavaScript;P...
# 43137                                                  Python
# 43138                       HTML/CSS;JavaScript;SQL;Other(s):
# 43139           C#;Dart;F#;HTML/CSS;JavaScript;SQL;TypeScript
#
#                                            DatabaseWorkedWith  \
# Respondent
# 1                                                      SQLite
# 2                                                         NaN
# 3                                                  PostgreSQL
# 4                                                MySQL;SQLite
# 5            Couchbase;MongoDB;MySQL;Oracle;PostgreSQL;SQLite
# ...                                                       ...
# 43135                               Firebase;MySQL;PostgreSQL
# 43136       Microsoft SQL Server;MySQL;Oracle;PostgreSQL;S...
# 43137                                                   MySQL
# 43138                                                  Oracle
# 43139                       Microsoft SQL Server;MySQL;Oracle
#
#                                        DatabaseDesireNextYear  \
# Respondent
# 1                                                       MySQL
# 2                                                       MySQL
# 3                                                  PostgreSQL
# 4                                                MySQL;SQLite
# 5           Couchbase;Firebase;MongoDB;MySQL;Oracle;Postgr...
# ...                                                       ...
# 43135       Cassandra;DynamoDB;Firebase;MongoDB;MySQL;Post...
# 43136       Cassandra;DynamoDB;Firebase;MySQL;PostgreSQL;S...
# 43137                                          MongoDB;Oracle
# 43138                                                  Oracle
# 43139                       Microsoft SQL Server;MySQL;SQLite
#
#                                            PlatformWorkedWith  \
# Respondent
# 1                                               MacOS;Windows
# 2                                                     Windows
# 3                                                         NaN
# 4                                               Linux;Windows
# 5                           Android;Linux;MacOS;Slack;Windows
# ...                                                       ...
# 43135       Android;AWS;Google Cloud Platform;IBM Cloud or...
# 43136       AWS;Docker;Google Cloud Platform;IBM Cloud or ...
# 43137                                               WordPress
# 43138                                               Other(s):
# 43139       Linux;Microsoft Azure;Raspberry Pi;Windows;Wor...
#
#                                        PlatformDesireNextYear  \
# Respondent
# 1                                     Android;Arduino;Windows
# 2                                                     Windows
# 3                                                         NaN
# 4                                               Linux;Windows
# 5                       Android;Docker;Kubernetes;Linux;Slack
# ...                                                       ...
# 43135       Android;AWS;Google Cloud Platform;IBM Cloud or...
# 43136       Android;Arduino;AWS;Docker;Google Cloud Platfo...
# 43137                                                 Android
# 43138                                               Other(s):
# 43139       Android;Arduino;Docker;Kubernetes;Linux;Micros...
#
#                                      WebFrameWorkedWith  \
# Respondent
# 1                                          Django;Flask
# 2                                                Django
# 3                                                   NaN
# 4                                                   NaN
# 5           Django;Express;Flask;jQuery;React.js;Spring
# ...                                                 ...
# 43135                                               NaN
# 43136                                      Django;Flask
# 43137                                            jQuery
# 43138                                            jQuery
# 43139               Angular/Angular.js;ASP.NET;React.js
#
#                                        WebFrameDesireNextYear  \
# Respondent
# 1                                                Flask;jQuery
# 2                                                      Django
# 3                                                   Other(s):
# 4                                                         NaN
# 5                                Flask;jQuery;React.js;Spring
# ...                                                       ...
# 43135       Angular/Angular.js;Django;Flask;jQuery;React.j...
# 43136                                   Django;Flask;React.js
# 43137                     Angular/Angular.js;Laravel;React.js
# 43138                                                     NaN
# 43139                     Angular/Angular.js;ASP.NET;React.js
#
#                                            MiscTechWorkedWith  \
# Respondent
# 1                                                     Node.js
# 2                                                         NaN
# 3                                                         NaN
# 4                                                        .NET
# 5                                             Cordova;Node.js
# ...                                                       ...
# 43135                                                     NaN
# 43136       Apache Spark;.NET;.NET Core;Pandas;TensorFlow;...
# 43137                                                     NaN
# 43138                                       Node.js;Other(s):
# 43139                                  .NET;.NET Core;Node.js
#
#                                        MiscTechDesireNextYear  \
# Respondent
# 1                                                     Node.js
# 2                                                         NaN
# 3                                                         NaN
# 4                                                        .NET
# 5                    Apache Spark;Hadoop;Node.js;React Native
# ...                                                       ...
# 43135       Apache Spark;Cordova;CryEngine;Hadoop;Pandas;T...
# 43136       Apache Spark;Flutter;Node.js;Pandas;TensorFlow...
# 43137                                                     NaN
# 43138                                       Node.js;Other(s):
# 43139                          Flutter;.NET;.NET Core;Node.js
#
#                                                    DevEnviron        OpSys  \
# Respondent
# 1                                  IntelliJ;Notepad++;PyCharm      Windows
# 2                                                Atom;PyCharm      Windows
# 3                                      Vim;Visual Studio Code  Linux-based
# 4                Eclipse;Vim;Visual Studio;Visual Studio Code      Windows
# 5                                      IntelliJ;Notepad++;Vim  Linux-based
# ...                                                       ...          ...
# 43135       Android Studio;Atom;IntelliJ;NetBeans;PyCharm;...  Linux-based
# 43136       Emacs;IPython / Jupyter;RStudio;Vim;Visual Stu...  Linux-based
# 43137                                            Sublime Text  Linux-based
# 43138                                      Visual Studio Code      Windows
# 43139       IntelliJ;Notepad++;Vim;Visual Studio;Visual St...      Windows
#
#                                                    Containers BlockchainOrg  \
# Respondent
# 1                                     I do not use containers           NaN
# 2                                     I do not use containers           NaN
# 3                                     I do not use containers           NaN
# 4                                     I do not use containers    Not at all
# 5                      Outside of work, for personal projects    Not at all
# ...                                                       ...           ...
# 43135                                 I do not use containers           NaN
# 43136       Development;Testing;Outside of work, for perso...           NaN
# 43137                                             Development           NaN
# 43138                  Outside of work, for personal projects           NaN
# 43139                  Outside of work, for personal projects    Not at all
#
#                                                  BlockchainIs BetterLife  \
# Respondent
# 1                                                         NaN        Yes
# 2           Useful across many domains and could change ma...        Yes
# 3                                                         NaN        Yes
# 4           Useful for decentralized currency (i.e., Bitcoin)        Yes
# 5                                                         NaN        Yes
# ...                                                       ...        ...
# 43135                                                     NaN        Yes
# 43136                                           A passing fad        Yes
# 43137                                                     NaN         No
# 43138                                                     NaN         No
# 43139       Useful across many domains and could change ma...        Yes
#
#                                             ITperson OffOn SocialMedia  \
# Respondent
# 1           Fortunately, someone else has that title   Yes     Twitter
# 2                                                Yes   Yes   Instagram
# 3                                                Yes   Yes      Reddit
# 4                                               SIGH   Yes      Reddit
# 5                                           Also Yes   Yes    Facebook
# ...                                              ...   ...         ...
# 43135                                            Yes   Yes     YouTube
# 43136                                            Yes   Yes     Twitter
# 43137       Fortunately, someone else has that title   Yes     YouTube
# 43138       Fortunately, someone else has that title   Yes     Twitter
# 43139                                       Also Yes   Yes    WhatsApp
#
#                         Extraversion ScreenName        SOVisit1st  \
# Respondent
# 1                             Online   Username              2017
# 2                             Online   Username              2017
# 3           In real life (in person)   Username              2011
# 4           In real life (in person)   Username              2014
# 5           In real life (in person)   Username  I don't remember
# ...                              ...        ...               ...
# 43135                         Online     Handle              2016
# 43136                         Online     Handle              2009
# 43137                         Online   Username               NaN
# 43138                         Online   Username  I don't remember
# 43139       In real life (in person)      Login              2010
#
#                                 SOVisitFreq  \
# Respondent
# 1           A few times per month or weekly
# 2                     Daily or almost daily
# 3                      A few times per week
# 4                     Daily or almost daily
# 5                    Multiple times per day
# ...                                     ...
# 43135                 Daily or almost daily
# 43136                Multiple times per day
# 43137                Multiple times per day
# 43138       A few times per month or weekly
# 43139                Multiple times per day
#
#                                                     SOVisitTo  \
# Respondent
# 1           Find answers to specific questions;Learn how t...
# 2           Find answers to specific questions;Learn how t...
# 3           Find answers to specific questions;Learn how t...
# 4           Find answers to specific questions;Pass the ti...
# 5                          Find answers to specific questions
# ...                                                       ...
# 43135       Find answers to specific questions;Contribute ...
# 43136       Find answers to specific questions;Learn how t...
# 43137       Find answers to specific questions;Learn how t...
# 43138                      Find answers to specific questions
# 43139       Find answers to specific questions;Contribute ...
#
#                            SOFindAnswer  \
# Respondent
# 1                    3-5 times per week
# 2                    3-5 times per week
# 3                   6-10 times per week
# 4                    1-2 times per week
# 5           More than 10 times per week
# ...                                 ...
# 43135       More than 10 times per week
# 43136       More than 10 times per week
# 43137       More than 10 times per week
# 43138           Less than once per week
# 43139       More than 10 times per week
#
#                                        SOTimeSaved  SOHowMuchTime  \
# Respondent
# 1                   Stack Overflow was much faster  31-60 minutes
# 2                   Stack Overflow was much faster  11-30 minutes
# 3                         They were about the same            NaN
# 4                   Stack Overflow was much faster  31-60 minutes
# 5                   Stack Overflow was much faster            NaN
# ...                                            ...            ...
# 43135                     They were about the same            NaN
# 43136               Stack Overflow was much faster    60+ minutes
# 43137           Stack Overflow was slightly faster  11-30 minutes
# 43138       The other resource was slightly faster   0-10 minutes
# 43139           Stack Overflow was slightly faster   0-10 minutes
#
#                             SOAccount  \
# Respondent
# 1                                  No
# 2                                 Yes
# 3                                 Yes
# 4                                 Yes
# 5                                 Yes
# ...                               ...
# 43135                             Yes
# 43136                             Yes
# 43137                             Yes
# 43138       Not sure / can't remember
# 43139                             Yes
#
#                                                    SOPartFreq  \
# Respondent
# 1                                                         NaN
# 2                             A few times per month or weekly
# 3                         Less than once per month or monthly
# 4                         Less than once per month or monthly
# 5                             A few times per month or weekly
# ...                                                       ...
# 43135                                   Daily or almost daily
# 43136                                  Multiple times per day
# 43137       I have never participated in Q&A on Stack Over...
# 43138                                                     NaN
# 43139                                   Daily or almost daily
#
#                                                        SOJobs  \
# Respondent
# 1           No, I didn't know that Stack Overflow had a jo...
# 2           No, I knew that Stack Overflow had a job board...
# 3                                                         Yes
# 4                                                         Yes
# 5           No, I knew that Stack Overflow had a job board...
# ...                                                       ...
# 43135                                                     Yes
# 43136                                                     Yes
# 43137                                                     Yes
# 43138       No, I didn't know that Stack Overflow had a jo...
# 43139                                                     Yes
#
#                                                      EntTeams  \
# Respondent
# 1                         No, and I don't know what those are
# 2                         No, and I don't know what those are
# 3           No, I've heard of them, but I am not part of a...
# 4                         No, and I don't know what those are
# 5           No, I've heard of them, but I am not part of a...
# ...                                                       ...
# 43135       No, I've heard of them, but I am not part of a...
# 43136       No, I've heard of them, but I am not part of a...
# 43137                     No, and I don't know what those are
# 43138                     No, and I don't know what those are
# 43139       No, I've heard of them, but I am not part of a...
#
#                      SOComm                             WelcomeChange  \
# Respondent
# 1                   Neutral   Just as welcome now as I felt last year
# 2             Yes, somewhat   Just as welcome now as I felt last year
# 3                   Neutral   Just as welcome now as I felt last year
# 4            No, not really   Just as welcome now as I felt last year
# 5           Yes, definitely   Just as welcome now as I felt last year
# ...                     ...                                       ...
# 43135       Yes, definitely     A lot more welcome now than last year
# 43136       Yes, definitely     A lot more welcome now than last year
# 43137       Yes, definitely   Just as welcome now as I felt last year
# 43138        No, not really   Just as welcome now as I felt last year
# 43139         Yes, somewhat  Somewhat more welcome now than last year
#
#                                                  SONewContent   Age Gender  \
# Respondent
# 1           Tech articles written by other developers;Indu...  14.0    Man
# 2           Tech articles written by other developers;Indu...  19.0    Man
# 3           Tech meetups or events in your area;Courses on...  28.0    Man
# 4           Tech articles written by other developers;Indu...  22.0    Man
# 5           Tech meetups or events in your area;Courses on...  30.0    Man
# ...                                                       ...   ...    ...
# 43135       Tech articles written by other developers;Indu...  22.0    Man
# 43136       Tech articles written by other developers;Tech...  29.0  Woman
# 43137                                                     NaN   NaN    Man
# 43138       Tech articles written by other developers;Indu...  33.0    Man
# 43139       Industry news about technologies you're intere...  28.0    Man
#
#            Trans                Sexuality  \
# Respondent
# 1             No  Straight / Heterosexual
# 2             No  Straight / Heterosexual
# 3             No  Straight / Heterosexual
# 4             No  Straight / Heterosexual
# 5             No  Straight / Heterosexual
# ...          ...                      ...
# 43135         No  Straight / Heterosexual
# 43136         No                      NaN
# 43137         No                      NaN
# 43138         No  Straight / Heterosexual
# 43139         No  Straight / Heterosexual
#
#                                                     Ethnicity Dependents  \
# Respondent
# 1                                                         NaN         No
# 2                                                         NaN         No
# 3                                                         NaN        Yes
# 4                                White or of European descent         No
# 5                    White or of European descent;Multiracial         No
# ...                                                       ...        ...
# 43135                                             South Asian         No
# 43136                            White or of European descent         No
# 43137                                                     NaN        Yes
# 43138                               Hispanic or Latino/Latina        Yes
# 43139       Black or of African descent;Hispanic or Latino...        Yes
#
#                      SurveyLength                  SurveyEase
# Respondent
# 1           Appropriate in length  Neither easy nor difficult
# 2           Appropriate in length  Neither easy nor difficult
# 3           Appropriate in length  Neither easy nor difficult
# 4           Appropriate in length                        Easy
# 5           Appropriate in length                        Easy
# ...                           ...                         ...
# 43135       Appropriate in length                        Easy
# 43136                    Too long  Neither easy nor difficult
# 43137                    Too long  Neither easy nor difficult
# 43138                    Too long                        Easy
# 43139       Appropriate in length                        Easy
#
# [42866 rows x 84 columns]
